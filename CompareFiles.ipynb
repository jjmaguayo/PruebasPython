# %%
#!conda activate tensorflow
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Reportes/Nuevos/datos_abiertos_covid19/COVID19_Mexico.csv", sep=',', index_col=0)
data.head(7)
# Out:
#                     ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# FECHA_ACTUALIZACION
# 2020-04-26               031e57       1       4           9     2
# 2020-04-26               0a9147       2      12          26     1
# 2020-04-26               0f671b       2      12           5     2
# 2020-04-26               15f384       2      12          25     1
# 2020-04-26               037e26       2       4          14     1
# 2020-04-26               07dda9       1       4          24     1
# 2020-04-26               1d487b       2       4          25     1
#
#                      ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# FECHA_ACTUALIZACION
# 2020-04-26                     9            9             16              2
# 2020-04-26                    26           26             30              1
# 2020-04-26                     5            5             30              1
# 2020-04-26                    25            2              5              2
# ...

# %%
dataH = pd.read_csv("Reportes/Nuevos/datos_abiertos_covid19/COVID19_Mexico_19.04.2020.csv", sep=',', index_col=0)
dataH.head(7)
# Out:
#                     ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# FECHA_ACTUALIZACION
# 2020-04-19               09e8dc       2       9          15     1
# 2020-04-19               1dd782       2      12           9     1
# 2020-04-19               0efbaf       2       9          28     2
# 2020-04-19               0e8ab4       2      12           9     2
# 2020-04-19               013a6c       1       3          15     2
# 2020-04-19               091a48       1      12          15     2
# 2020-04-19               1a5595       2      12           9     2
#
#                      ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# FECHA_ACTUALIZACION
# 2020-04-19                    15           15           37.0              2
# 2020-04-19                    15            9            3.0              1
# 2020-04-19                    16           28           32.0              1
# 2020-04-19                    99            9           13.0              1
# ...

# %%
print(data.columns)
print(dataH.columns)

data = data.set_index('ID_REGISTRO');
dataH = dataH.set_index('ID_REGISTRO');
# Out:
# Index(['ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM', 'SEXO', 'ENTIDAD_NAC',
#        'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE', 'FECHA_INGRESO',
#        'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA', 'EDAD',
#        'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES', 'EPOC',
#        'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM', 'CARDIOVASCULAR',
#        'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO', 'OTRO_CASO', 'RESULTADO',
#        'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI'],
#       dtype='object')
# Index(['ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM', 'SEXO', 'ENTIDAD_NAC',
#        'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE', 'FECHA_INGRESO',
#        'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA', 'EDAD',
#        'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES', 'EPOC',
#        'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM', 'CARDIOVASCULAR',
# ...

# %%
UnionDatos = dataH.join(data, lsuffix='_historic', rsuffix='_new')
#UnionDatos.head()
query1 = UnionDatos.query('FECHA_INGRESO_historic != FECHA_INGRESO_new')

#print(query1[['ORIGEN_new','FECHA_INGRESO_historic','FECHA_INGRESO_new','FECHA_SINTOMAS_historic','FECHA_SINTOMAS_new','FECHA_DEF_historic','FECHA_DEF_new']].head())

UnionDatos2 = data.join(dataH, lsuffix='_new', rsuffix='_historic')
#UnionDatos.head()
query2 = UnionDatos2.query('FECHA_INGRESO_historic != FECHA_INGRESO_new')

query2[['ORIGEN_new','FECHA_INGRESO_historic','FECHA_INGRESO_new','FECHA_SINTOMAS_historic','FECHA_SINTOMAS_new','FECHA_DEF_historic','FECHA_DEF_new']].head()

#fechas_serie = pd.date_range('20200101', periods=365, freq='D')
#fechas_dataFrame = (fechas_serie.to_frame(name='Fecha'))

#fechaSintomas = dataq1.groupby(['FECHA_SINTOMAS']).count()['DIAS_INGRESO_SINTOMAS'].to_frame(name='FECHA_SINTOMAS')
#fechaIngreso = dataq1.groupby(['FECHA_INGRESO']).count()['DIAS_INGRESO_SINTOMAS'].to_frame(name='FECHA_INGRESO')
# Out:
#              ORIGEN_new FECHA_INGRESO_historic FECHA_INGRESO_new  \
# ID_REGISTRO
# 031e57                1                    NaN        2020-04-17
# 037e26                2                    NaN        2020-02-12
# 0f7a51                2                    NaN        2020-04-21
# 13f04b                1                    NaN        2020-04-21
# 1c98c7                1                    NaN        2020-04-18
#
#             FECHA_SINTOMAS_historic FECHA_SINTOMAS_new FECHA_DEF_historic  \
# ID_REGISTRO
# 031e57                          NaN         2020-04-16                NaN
# 037e26                          NaN         2020-02-06                NaN
# 0f7a51                          NaN         2020-04-21                NaN
# 13f04b                          NaN         2020-04-18                NaN
# 1c98c7                          NaN         2020-04-15                NaN
#
#             FECHA_DEF_new
# ID_REGISTRO
# 031e57         9999-99-99
# 037e26         9999-99-99
# ...
